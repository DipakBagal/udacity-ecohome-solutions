# %% [markdown]
# # EcoHome Energy Advisor - Colab Quick Start
#
# Simple setup to test the EcoHome agent in Google Colab.

# %%
# Step 1: Clone and install
# !git clone https://github.com/DipakBagal/udacity-ecohome-solutions.git
# %cd udacity-ecohome-solutions
# !pip install -q langchain langchain-openai langchain-community langgraph chromadb sqlalchemy python-dotenv

# %%
# Step 2: Set API key
import os
os.environ["OPENAI_API_KEY"] = "sk-proj-YOUR-KEY-HERE"
print("API key set" if os.environ["OPENAI_API_KEY"].startswith("sk-") else "Set your API key above!")

# %%
# Step 3: Run all setup notebooks
# %run 01_db_setup.ipynb
# %run 02_rag_setup.ipynb
# %run 03_run_and_evaluate.ipynb
